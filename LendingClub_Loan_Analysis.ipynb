# %% [markdown]
# <a href='https://www.lendingclub.com/'><img src='Images/lendingclub.png' width=300 height=300/></a>
# # <center>LendingClub Loan Analysis<center/>

# %% [markdown]
# ## Table of Contents:
# 1. <a href="#1.-Data-Cleaning">Data Cleaning</a> <br>
#     1.1 <a href="#1.1-Packages-to-be-Imported">Packages to be Imported</a> <br>
#     1.2 <a href="#1.2-General-Info-about-the-Dataset">General Info about the Dataset</a> <br>
#     1.3 <a href="#1.3-Dealing-with-Missing-Values">Dealing with Missing Values</a> <br>
# <br>
# 2. <a href="#2.-Exploratory-Data-Analysis-(EDA)">Exploratory Data Analysis (EDA)</a> <br>
#     2.1 <a href="#2.1-Loan-Status-by-Categories">Loan Status by Categories</a> <br>
#     2.2 <a href="#2.2-Total-Loans-Issued-by-Year">Total Loans Issued by Year</a> <br>
#     2.3 <a href="#2.3-Loan-Amount-by-Barrower-Purposes">Loan Amount by Barrower Purposes</a> <br>
#     2.4 <a href="#2.4-Loan-Status-by-Borrower-Purpose">Loan Status by Borrower Purposes</a> <br>
#     2.5 <a href="#2.5-Interest-Rate-by-Grade-Category">Interest Rate by Grade Category</a> <br>
#     2.6 <a href="#2.6-Loan-Status-by-Grade-Category">Loan Status by Grade Category</a> <br>
#     2.7 <a href="#2.7-Good-loan-vs-Bad-Loan-by-Interest-Rate">Good Loan vs Bad Loan by Interest Rate</a> <br>
#     2.8 <a href="#2.8-Distribution-of-Homeownership">Distribution of Homeownership</a> <br>
#     2.9 <a href="#2.9-Loan-Status-by-Homeownership">Loan Status by Homeownership</a> <br>
#     2.10 <a href="#2.10-Loan-Status-by-Employment-Length">Loan Status by Employment Length</a> <br>
#     2.11 <a href="#2.11-Correlation-Between-Features">Correlation Between Features</a> <br>
# <br>
# 3. <a href="#3.-Feature-Selection">Feature Selection</a> <br>
#     3.1 <a href="#3.1-Dealing-with-the-Rows-Which-Contain-Missing-Values">Dealing with the Rows Which Contain Missing Values</a> <br>
#     3.2 <a href="#3.2-Converting-Loan-Status-into-Good-or-Bad-Loan">Converting Loan Status into Good or Bad Loan</a> <br>
#     3.3 <a href="#3.3-Feature-Selection-for-Object-Data-Type">Feature Selection for Object Data Type</a> <br>
#     3.4 <a href="#3.4-One-Hot-Encoding">One Hot Encoding</a> <br>
# <br>
# 4. <a href="#4.-Model-Building-(Imbalanced-Data)">Model Building (Imbalanced Data)</a> <br>
#     4.1 <a href="#4.1-Splitting-Data-into-Training-and-Test-Sets">Splitting Data into Training and Test Sets</a> <br>
#     4.2 <a href="#4.2-Feature-Scaling">Feature Scaling</a> <br>
#     4.3 <a href="#4.3-Model-Fitting">Model Fitting</a> <br>
#     4.3.1 <a href="#4.3.1-Logistic-Regression">Logistic Regression</a> <br>
#     4.3.2 <a href="#4.3.2-Decision-Tree">Decision Tree</a> <br>
#     4.3.3 <a href="#4.3.3-Random-Forest">Random Forest</a>
# <br>
# 5. <a href="#5.-Model-Building-(Balanced-Data)">Model Building (Balanced Data)</a> <br>
#     5.1 <a href="#5.1-Balancing-Training-Dataset---SMOTE">Balancing Training Dataset - SMOTE</a> <br>
#     5.2 <a href="#5.2-Model-Fitting">Model Fitting</a> <br>
#     5.2.1 <a href="#5.2.1-Logistic-Regression">Logistic Regression</a> <br>
#     5.2.2 <a href="#5.2.2-Decision-Tree">Decision Tree</a> <br>
#     5.2.3 <a href="#5.2.3-Random-Forest">Random Forest</a> <br>
# <br>
# 6. <a href="#6.-Conclusion">Conclusion</a> <br>

# %% [markdown]
# ##### About the LendingClub:
#
# LendingClub is an American peer-to-peer lending company, headquartered in San Francisco, California. The company offers loan trading on a secondary market by bringing borrowers and investors together. The company claims that $15.8 billion in loans has issued for millions of people between the years of 2007 and 2015. LendingClub offers a variety of loan option for consumers and businesses including personal loans, business loans, patient solutions, and K-12 education loans.
#
# _How it Works:_
#
# Individual borrowers can apply online for a personal loan through LendingClub. They can select a loan offer after reviewing their monthly payment and interest rate options. Once approved, the loan is deposited into the borrower's bank account. Personal loans can range from \\$1,000 to $40,000 depending upon the information provided and credit report. Two active personal loans are allowed at the same time.

# %% [markdown]
# ![Screen%20Shot%202020-02-21%20at%209.47.18%20AM.png](attachment:Screen%20Shot%202020-02-21%20at%209.47.18%20AM.png)

# %% [markdown]
# Investors, on the other hand, put funds in SEC-registered securities called Member Payment Dependent Notes, which form fractions of loans instead of making loans directly to the borrowers. Investors receive monthly payments out of principal and interest payments. LendingClub makes money by charging borrowers an origination fee and investors a service fee.

# %% [markdown]
# ![Screen%20Shot%202020-02-21%20at%209.51.45%20AM.png](attachment:Screen%20Shot%202020-02-21%20at%209.51.45%20AM.png)

# %% [markdown]
# ##### Problem Statement:
# Loan default is the failure to pay back a debt according to initial arrangement. It causes huge loss to the banks and lenders, so they pay much attention on loan defaults and apply various methods to detect and predict default behaviors of their customers. Machine learning algorithms which have a good performance on this purpose, are widely used in banking and lending.
#
# In this project, I will develop various machine learning models in order to correctly detect and predict good (low risk) and bad (high risk) loans using the LendingClub Loan Data. The machine learning models would bring added value by minimizing the associated risks and the LendingClub can decide whether a person is fit for a loan or not in the future. An exploratory data analysis (EDA) will be initially performed to develop insight about the data and features. After getting the data ready for the analysis, various machine learning models will be developed to correctly identify and predict good and bad loans. The analyses will also provide insightful recommendations and future steps that the LendingClub managers and investors might want to take into consideration.

# %% [markdown]
# ##### About the Dataset:
# The data for the analyses were acquired from Kaggle.com - Lending Club Loan Data. The data contain about 890 thousand observations and 75 features including loan amount, funded loan amount, interest rate, credit scores, employment length, homeownership, annual income, address including zip codes, and state, and collections. A data dictionary is provided in a separate file. The dataset used for this project can be acquired using the following link: https://www.kaggle.com/wendykan/lending-club-loan-data

# %% [markdown]
# # 1. Data Cleaning

# %% [markdown]
# Before we leap over our analysis in the subsequent chapters, a data wrangling process will be performed to inspect the data, to look for missing values, and to clean data to get ready for the further analysis.

# %% [markdown]
# #### 1.1 Packages to be Imported

# %% [markdown]
# This section sets up all the necessary packages that will be used throughout this project.

# %%
# perform the necessary imports here
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split, cross_val_score 
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### 1.2 General Info about the Dataset

# %% [markdown]
# Let's start with reading the data into a dataframe and printing its head in order to develop insight into the data.

# %%
# read data into a dataframe
df = pd.read_csv('data/loan.csv', low_memory=False)

# print the head of the data to have an insight
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... total_bal_il il_util  \
# 0     10.65       162.87     B        B2  ...          NaN     NaN
# 1     15.27        59.83     C        C4  ...          NaN     NaN
# 2     15.96        84.33     C        C5  ...          NaN     NaN
# 3     13.49       339.31     C        C1  ...          NaN     NaN
# 4     12.69        67.79     B        B5  ...          NaN     NaN
#
#   open_rv_12m  open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi  \
# 0         NaN          NaN        NaN      NaN              NaN    NaN
# 1         NaN          NaN        NaN      NaN              NaN    NaN
# 2         NaN          NaN        NaN      NaN              NaN    NaN
# 3         NaN          NaN        NaN      NaN              NaN    NaN
# 4         NaN          NaN        NaN      NaN              NaN    NaN
#
#   total_cu_tl inq_last_12m
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
#
# [5 rows x 74 columns]

# %% [markdown]
# As can be seen from the head of the dataset, there are some columns which have `NaN` values. We will be taking care of those values when dealing with the missing values in the dataset.

# %%
# print the shape of the data
df.shape
# Out:
# (887379, 74)

# %% [markdown]
# The entire dataset has overall 887,379 rows(observations) and 74 columns(features).

# %%
# print the info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           887379 non-null  int64
#  1   member_id                    887379 non-null  int64
#  2   loan_amnt                    887379 non-null  float64
#  3   funded_amnt                  887379 non-null  float64
#  4   funded_amnt_inv              887379 non-null  float64
#  5   term                         887379 non-null  object
#  6   int_rate                     887379 non-null  float64
#  7   installment                  887379 non-null  float64
#  8   grade                        887379 non-null  object
#  9   sub_grade                    887379 non-null  object
#  10  emp_title                    835917 non-null  object
#  11  emp_length                   842554 non-null  object
#  12  home_ownership               887379 non-null  object
#  13  annual_inc                   887375 non-null  float64
#  14  verification_status          887379 non-null  object
#  15  issue_d                      887379 non-null  object
#  16  loan_status                  887379 non-null  object
#  17  pymnt_plan                   887379 non-null  object
#  18  url                          887379 non-null  object
#  19  desc                         126028 non-null  object
#  20  purpose                      887379 non-null  object
#  21  title                        887227 non-null  object
#  22  zip_code                     887379 non-null  object
#  23  addr_state                   887379 non-null  object
#  24  dti                          887379 non-null  float64
#  25  delinq_2yrs                  887350 non-null  float64
#  26  earliest_cr_line             887350 non-null  object
#  27  inq_last_6mths               887350 non-null  float64
#  28  mths_since_last_delinq       433067 non-null  float64
#  29  mths_since_last_record       137053 non-null  float64
#  30  open_acc                     887350 non-null  float64
#  31  pub_rec                      887350 non-null  float64
#  32  revol_bal                    887379 non-null  float64
#  33  revol_util                   886877 non-null  float64
#  34  total_acc                    887350 non-null  float64
#  35  initial_list_status          887379 non-null  object
#  36  out_prncp                    887379 non-null  float64
#  37  out_prncp_inv                887379 non-null  float64
#  38  total_pymnt                  887379 non-null  float64
#  39  total_pymnt_inv              887379 non-null  float64
#  40  total_rec_prncp              887379 non-null  float64
#  41  total_rec_int                887379 non-null  float64
#  42  total_rec_late_fee           887379 non-null  float64
#  43  recoveries                   887379 non-null  float64
#  44  collection_recovery_fee      887379 non-null  float64
#  45  last_pymnt_d                 869720 non-null  object
#  46  last_pymnt_amnt              887379 non-null  float64
#  47  next_pymnt_d                 634408 non-null  object
#  48  last_credit_pull_d           887326 non-null  object
#  49  collections_12_mths_ex_med   887234 non-null  float64
#  50  mths_since_last_major_derog  221703 non-null  float64
#  51  policy_code                  887379 non-null  float64
#  52  application_type             887379 non-null  object
#  53  annual_inc_joint             511 non-null     float64
#  54  dti_joint                    509 non-null     float64
#  55  verification_status_joint    511 non-null     object
#  56  acc_now_delinq               887350 non-null  float64
#  57  tot_coll_amt                 817103 non-null  float64
#  58  tot_cur_bal                  817103 non-null  float64
#  59  open_acc_6m                  21372 non-null   float64
#  60  open_il_6m                   21372 non-null   float64
#  61  open_il_12m                  21372 non-null   float64
#  62  open_il_24m                  21372 non-null   float64
#  63  mths_since_rcnt_il           20810 non-null   float64
#  64  total_bal_il                 21372 non-null   float64
#  65  il_util                      18617 non-null   float64
#  66  open_rv_12m                  21372 non-null   float64
#  67  open_rv_24m                  21372 non-null   float64
#  68  max_bal_bc                   21372 non-null   float64
#  69  all_util                     21372 non-null   float64
#  70  total_rev_hi_lim             817103 non-null  float64
#  71  inq_fi                       21372 non-null   float64
#  72  total_cu_tl                  21372 non-null   float64
#  73  inq_last_12m                 21372 non-null   float64
# dtypes: float64(49), int64(2), object(23)
# memory usage: 501.0+ MB

# %% [markdown]
# Here, we can see a lot of information about our dataset, including total number of entries and columns, column names and data types for each column. Again, we see that there are some columns with a huge number of missing values. We also need to gather further information to check if the values here are consistent using pandas `describe()` method.

# %%
df.describe()
# Out:
#                  id     member_id      loan_amnt    funded_amnt  \
# count  8.873790e+05  8.873790e+05  887379.000000  887379.000000
# mean   3.246513e+07  3.500182e+07   14755.264605   14741.877625
# std    2.282734e+07  2.411335e+07    8435.455601    8429.897657
# min    5.473400e+04  7.047300e+04     500.000000     500.000000
# 25%    9.206643e+06  1.087713e+07    8000.000000    8000.000000
# 50%    3.443327e+07  3.709528e+07   13000.000000   13000.000000
# 75%    5.490814e+07  5.847135e+07   20000.000000   20000.000000
# max    6.861706e+07  7.354484e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    887379.000000  887379.000000  887379.000000  8.873750e+05
# mean      14702.464383      13.246740     436.717127  7.502759e+04
# std        8442.106732       4.381867     244.186593  6.469830e+04
# min           0.000000       5.320000      15.670000  0.000000e+00
# 25%        8000.000000       9.990000     260.705000  4.500000e+04
# 50%       13000.000000      12.990000     382.550000  6.500000e+04
# 75%       20000.000000      16.200000     572.600000  9.000000e+04
# max       35000.000000      28.990000    1445.460000  9.500000e+06
#
#                  dti    delinq_2yrs  ...   total_bal_il       il_util  \
# count  887379.000000  887350.000000  ...   21372.000000  18617.000000
# mean       18.157039       0.314442  ...   36552.811389     71.535317
# std        17.190626       0.862244  ...   43103.833619     23.022862
# min         0.000000       0.000000  ...       0.000000      0.000000
# 25%        11.910000       0.000000  ...   10251.500000     58.600000
# 50%        17.650000       0.000000  ...   24684.500000     74.900000
# 75%        23.950000       0.000000  ...   47858.000000     87.600000
# max      9999.000000      39.000000  ...  878459.000000    223.300000
#
#         open_rv_12m   open_rv_24m     max_bal_bc      all_util  \
# count  21372.000000  21372.000000   21372.000000  21372.000000
# mean       1.389060      2.975482    5887.979740     60.831939
# std        1.520129      2.631886    5284.701239     20.013254
# min        0.000000      0.000000       0.000000      0.000000
# 25%        0.000000      1.000000    2411.000000     47.700000
# 50%        1.000000      2.000000    4483.000000     61.900000
# 75%        2.000000      4.000000    7771.500000     75.200000
# max       22.000000     43.000000  127305.000000    151.400000
#
#        total_rev_hi_lim        inq_fi   total_cu_tl  inq_last_12m
# count      8.171030e+05  21372.000000  21372.000000  21372.000000
# mean       3.206862e+04      0.943945      1.537058      1.977307
# std        3.749826e+04      1.446872      2.723339      2.874067
# min        0.000000e+00      0.000000      0.000000     -4.000000
# 25%        1.390000e+04      0.000000      0.000000      0.000000
# 50%        2.370000e+04      0.000000      0.000000      2.000000
# 75%        3.980000e+04      1.000000      2.000000      3.000000
# max        9.999999e+06     17.000000     35.000000     32.000000
#
# [8 rows x 51 columns]

# %% [markdown]
# Pandas `describe()` method helps us understand the numerical attributes and outliers if any. Out of 887,379 loans provided to the borrowers, the amount of loans given ranges from \\$500 to $35,000 with an average interest rate of 12.99

# %%
len(df.id.unique())
# Out:
# 887379

# %% [markdown]
# Counting the unique values of id attribute shows us how many unique individuals/borrowers we are dealing with. In this case, there are 887,379 individuals which indicates that each enrty is unique to an individual.

# %% [markdown]
# #### 1.3 Dealing with the Features with Missing Values

# %% [markdown]
# To have a visual insight into the dataset, the following heatmap was produced. Yellow color accounts for the missing values in that particular column. The graph clearly illustrates that some columns, especially the ones near to the right side, have only a few observations/entries.

# %%
# perform a heatmap analysis for the missing values
_ = plt.figure(figsize=(10,6))
_ = sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# display the heatmap
plt.show()

# %% [markdown]
# Alternatively, we can print the number of missing values exist per column with their percentages out of the length of the dataframe.

# %%
# creating a separate dataframe to account for the number and percentanges of missing values
df_null = pd.DataFrame({'Count':df.isnull().sum(), 'Percent':100*df.isnull().sum()/len(df)})

# columns that have missing values more than 0
df_null[df_null['Count']>0]
# Out:
#                               Count    Percent
# emp_title                     51462   5.799326
# emp_length                    44825   5.051393
# annual_inc                        4   0.000451
# desc                         761351  85.797726
# title                           152   0.017129
# delinq_2yrs                      29   0.003268
# earliest_cr_line                 29   0.003268
# inq_last_6mths                   29   0.003268
# mths_since_last_delinq       454312  51.197065
# mths_since_last_record       750326  84.555303
# open_acc                         29   0.003268
# pub_rec                          29   0.003268
# revol_util                      502   0.056571
# total_acc                        29   0.003268
# last_pymnt_d                  17659   1.990018
# next_pymnt_d                 252971  28.507661
# last_credit_pull_d               53   0.005973
# collections_12_mths_ex_med      145   0.016340
# mths_since_last_major_derog  665676  75.015974
# annual_inc_joint             886868  99.942415
# dti_joint                    886870  99.942640
# verification_status_joint    886868  99.942415
# acc_now_delinq                   29   0.003268
# tot_coll_amt                  70276   7.919502
# tot_cur_bal                   70276   7.919502
# open_acc_6m                  866007  97.591559
# open_il_6m                   866007  97.591559
# open_il_12m                  866007  97.591559
# open_il_24m                  866007  97.591559
# mths_since_rcnt_il           866569  97.654892
# total_bal_il                 866007  97.591559
# il_util                      868762  97.902024
# open_rv_12m                  866007  97.591559
# open_rv_24m                  866007  97.591559
# max_bal_bc                   866007  97.591559
# all_util                     866007  97.591559
# total_rev_hi_lim              70276   7.919502
# inq_fi                       866007  97.591559
# total_cu_tl                  866007  97.591559
# inq_last_12m                 866007  97.591559

# %% [markdown]
# Here, again we confirmed that some columns have only a few entries. Hence, we decided to drop those columns that have 80% or more missing values.

# %%
# drop columns that have 80% or more missing values and assign it to a new dataframe
df1 = df.dropna(axis=1, thresh=int(0.80*len(df))).copy()

# %%
# check the shape of the original dataframe
df.shape
# Out:
# (887379, 74)

# %%
# check the shape of the new dataframe after dropping the columns with 80% or more missing values
df1.shape
# Out:
# (887379, 52)

# %% [markdown]
# After dropping the features with only a few number of entries, a total of 52 features were obtained. The following features were also dropped from the dataframe due to the fact that they have low variance. The "url" feature has a unique value for each entry which can lead to overfitting. Hence they need to be removed from the dataset as well.

# %%
# drop the following collumns
df1.drop(['id', 'member_id', 'policy_code', 'url', 'zip_code', 'last_pymnt_d'], axis=1, inplace=True)

# %% [markdown]
# One last time, we need to check the total number of the missing values and the percentages of the missing values for each column.

# %%
# creating a separate dataframe to account for the number and percentanges of missing values
df_null = pd.DataFrame({'Count':df1.isnull().sum(), 'Percent':100*df1.isnull().sum()/len(df1)})

# columns that have missing values more than 0
df_null[df_null['Count']>0]
# Out:
#                             Count   Percent
# emp_title                   51462  5.799326
# emp_length                  44825  5.051393
# annual_inc                      4  0.000451
# title                         152  0.017129
# delinq_2yrs                    29  0.003268
# earliest_cr_line               29  0.003268
# inq_last_6mths                 29  0.003268
# open_acc                       29  0.003268
# pub_rec                        29  0.003268
# revol_util                    502  0.056571
# total_acc                      29  0.003268
# last_credit_pull_d             53  0.005973
# collections_12_mths_ex_med    145  0.016340
# acc_now_delinq                 29  0.003268
# tot_coll_amt                70276  7.919502
# tot_cur_bal                 70276  7.919502
# total_rev_hi_lim            70276  7.919502

# %% [markdown]
# ------------------------

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# This section focuses on exploratory data analysis (EDA) which allows us to understand emerging themes before moving onto deeper and more complex data analysis.

# %% [markdown]
# #### 2.1 Loan Status by Categories

# %% [markdown]
# The following bar plot displays the distribution of loan status by categories. This bar plot gives us insight about how the data are distributed across loan status. A big percentage of loans are currently being paid while a fair amount of loans were fully paid. The other categories, on the other hand, have relatively smaller percentages. The categories of "Charged Off" and "Default" corresponds to respectively %5.10 and 0.14% of the entire loans issued by the LendingClub. These numbers indicate that the data are imbalanced which needs to be taken into account when building our predictive models.

# %%
# plot the categories of loan status column
_ = plt.figure(figsize=(10,5))
ax = sns.countplot(x='loan_status', data=df1, order=df1['loan_status'].value_counts().index)
_ = plt.title('Distribution of Loan Status by Categories', fontsize=14, fontweight='bold')
_ = plt.ylabel('Count')
_ = plt.xlabel('Loan Categories')
_ = plt.xticks(rotation=20)

# calculate the percentages of the loan status category
sizes=[]
total_data = len(df1)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,height + 6000,
            '{:1.2f}%'.format(height/total_data*100), ha="center", fontsize=10)

# display the plot
plt.show()

# %% [markdown]
# #### 2.2 Total Loans Issued by Year

# %% [markdown]
# The count of total loans issued by the LendingClub over the years displayed below. As can be seen from the chart, the number of loans issued is increasing over the years with the highest in 2015.

# %%
# exract the year and month values from issue_f feature
df1['issue_month'], df1['issue_year'] = df1['issue_d'].str.split('-', 1).str

# create a countplot for total loans issued by year
_ = plt.figure(figsize=(10,5))
ax = sns.countplot(x='issue_year', data=df1, color='#85bb65')
#plt.gca().invert_yaxis()
_ = plt.title('Total Loans Issued by Year', fontsize=12, 
              fontweight='bold')
_ = plt.ylabel('Total Loan')
_ = plt.xlabel('Years')
_ = ax.get_yaxis().set_major_formatter(matplotlib.ticker \
                                       .FuncFormatter(lambda x, p: format(int(x), ',')))

# calculate the percentages of the loan amounts by year
sizes=[]
total_data = len(df1)
for p in ax.patches:
    height = p.get_height()
    sizes.append(height)
    ax.text(p.get_x()+p.get_width()/2.,height + 3000,
            '{:1.2f}%'.format(height/total_data*100),
            ha="center", fontsize=12)

# display the plot
plt.show()

# %% [markdown]
# #### 2.3 Loan Amount by Barrower Purposes

# %% [markdown]
# The amount of loan issued by the LendingClub varies across the borrowers' purposes listed below. The largest amount of loan was issued for the borrowers with credit card, debt consolidation, and small business purposes.

# %%
_ = plt.figure(figsize=(10,5))
_ = sns.barplot(x='purpose', y='loan_amnt', data=df1, palette='tab20')
_ = plt.xticks(rotation=45)

# %% [markdown]
# #### 2.4 Loan Status by Borrower Purpose

# %% [markdown]
# An additional chart is produced below to provide insight about the share of loan status by borrower purpose. Borrowers with educational, small business and wedding purposes have a greater percentage to be charged off than the borrowers with other purposes.

# %%
# cross-tabulate "loan status" and "purpose" columns
tab = pd.crosstab(df1['purpose'], df1['loan_status'], 
                  normalize='index')*100

# create a stacked plot 
_ = plt.figure(figsize=(10,5))
_ = tab.plot(kind='bar',stacked=True, ax=plt.gca(), colormap='tab20')
_ = plt.xlabel('Borrower Purpose')
_ = plt.ylabel('Share of Loan Status (%)')
_ = plt.title('Share of Loan Status by Borrower Purpose')
_ = plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)

# display the chart
plt.show()

# %% [markdown]
# #### 2.5 Interest Rate by Grade Category

# %% [markdown]
# The violinplot below clearly illustrates that interest rate increases as loan grade category moves from A to G. It means that borrowers with a bad loan grade category are likely to have higher interest rate for the loans than the borrowers with a good loan grade category. The violinplot also shows that the average interest rate for the borrowers with "A" laon grade is 7.24, while it is 25.63 for the borrowers with "G" loan grade category. It also must be noted that the variation in interest rate is mostly increasing as the loan grade category moves from "A" to "F".

# %%
_ = plt.figure(figsize=(10,5))
_ = sns.violinplot(x="grade", y="int_rate", data=df1, order="ABCDEFG")
_ = plt.xlabel('Loan Grade Category')
_ = plt.ylabel('Interest Rate')
_ = plt.title('Distribution of Interest Rate\nby Loan Grade Category')

# display the plot
plt.show()

# %% [markdown]
# #### 2.6 Loan Status by Grade Category

# %% [markdown]
# The cross-tabulation of loan status and loan grade categories is displayed below. The table shows that almost 70% of the borrowers with "A" loan grade category are currently paying their loans, while almost 27% of them fully paid their loans. The borrowers with a "G" loan grade category have a high percentage of being currently paying their loans. When we look at the loan defaults and charged offs, individuals with "G" loan category have relatively higher percentages to be defaulted or charged off than the other loan grade categories. However, the percentage for loan defaults is relatively small only at 0.4%.

# %%
cm = sns.light_palette("green", as_cmap=True)
loan_by_grade = pd.crosstab(df1['loan_status'], df1['grade'], normalize='columns')*100
loan_by_grade.style.background_gradient(cmap=cm).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c304b326_5a4a_11ea_bca2_086d41bf696crow0_col0 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow0_col1 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow0_col2 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow0_col3 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow0_col4 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow0_col5 {
#             background-color:  #b5e4b5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow0_col6 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow1_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow1_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow1_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow1_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow2_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow3_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow3_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow3_col6 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow4_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow4_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow4_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow4_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow4_col6 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow5_col0 {
#             background-color:  #8dce8d;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow5_col1 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow5_col2 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow5_col3 {
#             background-color:  #9bd69b;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow5_col4 {
#             background-color:  #a7dda7;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow5_col5 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow5_col6 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow6_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow6_col3 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow6_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow6_col5 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow6_col6 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow7_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow7_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow7_col2 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow7_col3 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow7_col4 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow7_col5 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow7_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow8_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c304b326_5a4a_11ea_bca2_086d41bf696crow8_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;

# %% [markdown]
# #### 2.7 Good loan vs Bad Loan by Interest Rate

# %% [markdown]
# Here, we convert the loan status categories into good loan and bad loan and check to see whether the LendingClub give significantly different interest rate for good loans and bad loans.
#
# __$H_{0}$ :__ Good loans and bad loans are not different in terms of interest rates. <br>
# __$H_{a}$ :__ Good loans and bad loans are different in terms of interest rates.
#
# The small p value (<0.05) indicates that we need to reject the null hypothesis. It means that good loans and bad loans are different in terms of interest rates. In other words, theL LendingClub give significantly different interest rates for the loan categories which are considered to be good and for the loan categories which are considered to be bad.

# %%
# the loan status categories to be coverted to bad loan
bad_loan = ['Charged Off', 'Default', 'Late (16-30 days)','Late (31-120 days)']

def convert_loan_status(status):
    """This function converts the loan status feature into good or bad loan"""
    if status in bad_loan:
        return 'Bad Loan'
    else:
        return 'Good Loan'

# apply the function above to the "loan_status" feature
df['loan_status_temp'] = df['loan_status'].apply(convert_loan_status)

# %%
# extract interest rate for good loans and bad loans
bad_loan = df['int_rate'][df['loan_status_temp']=='Bad Loan'] 
good_loan = df['int_rate'][df['loan_status_temp']=='Good Loan']

# %%
# mean and standard deviation of interest rate for good loans and bad loans
bad_loan_mean = np.mean(bad_loan)
print(f'Average interest rate for bad loans is {bad_loan_mean}')

good_loan_mean = np.mean(good_loan)
print(f'Average interest rate for bad loans is {good_loan_mean}')
# Out:
# Average interest rate for bad loans is 16.003861292723457
# Average interest rate for bad loans is 13.045314342628133

# %%
t, p_val = stats.ttest_ind(bad_loan, good_loan, equal_var = False)
print(t, p_val)
# Out:
# 162.80377190990728 0.0

# %% [markdown]
# #### 2.8 Distribution of Homeownership

# %% [markdown]
# The distribution of homeownership shows that almost 50% of the borrowers have Mortgage, followed by the borrowers who are paying rent with a percentage of 40.13%. The borrowers who own homes correspond to 9.86% of the all the individuals applied for the loan from the LendingClub.

# %%
_ = plt.figure(figsize=(10,5))
ax = sns.countplot(x='home_ownership', data=df1, 
                   order = df1['home_ownership'].value_counts().index, 
                   color='cyan')
_ = plt.xlabel('Home Ownership')
_ = plt.ylabel('Count')
_ = plt.title('Distribution of Homeownership')

total = len(df1)
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 5
    y = p.get_y() + p.get_height() + 4000
    ax.annotate(percentage, (x, y))

# display the plot
plt.show()

# %% [markdown]
# #### 2.9 Loan Status by Homeownership

# %% [markdown]
# The cross-tabulation of loan status and homeownership features is provided below. The table shows that almost 70% of the borrowers with Mortgage is currently paying for their loans to the LendingClub, while almost 24% of them fully paid their loans. A big percentage of the borrowers who pay rent for their homes are similarly currently paying their loans. However, they have greater percentage to be charged off for their loans than the borrowers with Mortgage.

# %%
cm = sns.light_palette("green", as_cmap=True)
loan_by_homeownership = pd.crosstab(df1['loan_status'], df1['home_ownership'],normalize='columns')*100
loan_by_homeownership.style.background_gradient(cmap = cm).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow0_col1 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow0_col2 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow0_col3 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow0_col4 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow0_col5 {
#             background-color:  #d2f4d2;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow1_col2 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow1_col3 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow1_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow1_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow2_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow2_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow2_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow2_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow3_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow3_col2 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow3_col3 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow3_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow4_col2 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow4_col3 {
#             background-color:  #b0e1b0;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow4_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow4_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow5_col0 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow5_col1 {
#             background-color:  #96d396;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow5_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow5_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow5_col4 {
#             background-color:  #a4dba4;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow5_col5 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow6_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow6_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow6_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow6_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow6_col4 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow6_col5 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow7_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow7_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow7_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow7_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow7_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow7_col5 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow8_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow8_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow8_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow8_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow8_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow8_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow9_col1 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow9_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow9_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow9_col4 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_c3a33f00_5a4a_11ea_bca2_086d41bf696crow9_col5 {
#             background-color:  #e1fde1;
#             color:  #000000;

# %% [markdown]
# #### 2.10 Loan Status by Employment Length

# %% [markdown]
# The length of employment is another factor considered before issuing loans by the loan companies. However, as the cross-tabulation table indicates, there is no clear pattern between the loan status categories and the length of employment.

# %%
cm = sns.light_palette("red", as_cmap=True)
loan_by_employment = pd.crosstab(df1['loan_status'],df1['emp_length'], normalize='columns')*100
loan_by_employment.style.background_gradient(cmap = cm).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col0 {
#             background-color:  #ffd4d4;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col1 {
#             background-color:  #ffd7d7;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col2 {
#             background-color:  #ffd4d4;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col3 {
#             background-color:  #ffd5d5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col4 {
#             background-color:  #ffd3d3;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col5 {
#             background-color:  #ffd2d2;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col6 {
#             background-color:  #ffcfcf;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col7 {
#             background-color:  #ffd2d2;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col8 {
#             background-color:  #ffd6d6;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col9 {
#             background-color:  #ffd5d5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow0_col10 {
#             background-color:  #ffd3d3;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col0 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col4 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col5 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col6 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col7 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col8 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col9 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow1_col10 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col7 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col8 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col9 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow2_col10 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col7 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col8 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col9 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow3_col10 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col7 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col8 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col9 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow4_col10 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow5_col0 {
#             background-color:  #ff9292;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow5_col1 {
#             background-color:  #ff9e9e;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow5_col2 {
#             background-color:  #ff9090;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow5_col3 {
#             background-color:  #ff9494;
#             color:  #000000;
#         }    #T_c3c8d990_5a4a_11ea_bca2_086d41bf696crow5_col4 {
#             background-color:  #ff8c8c;
#             color:  #000000

# %% [markdown]
# #### 2.11 Correlation Between Features

# %% [markdown]
# Before looking at the correlation structure between the features in our project, we need to convert the features with "Object" data type to "Categorical" data type. A total of 19 features has object data type.

# %%
# define a temporary data frame
df_temp = df1.copy()

# %%
# select the features with "Object" data type
df_Obj = df_temp.select_dtypes(include='object')

# check the number of columns with "Object" data type
df_Obj.shape
# Out:
# (887379, 19)

# %%
# define a lambda function to be used to convert object type to 
# categorical data type
categorize_label = lambda x: x.astype('category').cat.codes

# convert the columns with "Object" data type to "Categorical" data type
df_temp[df_Obj.columns] = df_temp[df_Obj.columns].apply(categorize_label, axis=0)

# %% [markdown]
# Since we have so many columns, we divide the entire dataset into two parts in order to create the correlation matrix using the heatmap below.

# %%
temp_features=df_temp.drop('loan_status',axis=1).columns
x1=list(temp_features[:24])
x1.append('loan_status')
x2=list(temp_features[24:len(temp_features)])
x2.append('loan_status')

# %%
_ = plt.figure(figsize=(25,20))
_ = sns.set(font_scale=1.3)
ax = sns.heatmap(df_temp[x1].corr(), vmin=-1, vmax=1,square=True, 
                 annot=True, cmap='bwr', cbar=True, fmt=".2f")
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# display the heatmap
plt.show()

# %%
_ = plt.figure(figsize=(25,20))
ax = sns.heatmap(df_temp[x2].corr(), vmin=-1, vmax=1,square=True, 
                 annot=True, cmap='bwr', cbar=True, fmt=".2f")
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# display the heatmap
plt.show()

# %% [markdown]
# The correlation heatmap above clearly illustrates the relationships between the variables of interest. While the red color indicates a positive correlation between the two variables, blue color indicates negative correlation. The strength of correlations has also been added on the heatmap above. As an example, there is a positive strong correlation between loan amount and installment as expected. It also must be noted that correlation does not imply causation.
#
# The features with high correlation will also be dropped in the following section, because only one of them will be sufficent to feed the machine learning models.

# %% [markdown]
# --------------

# %% [markdown]
# # 3. Feature Selection

# %% [markdown]
# #### 3.1 Dealing with the Rows Which Contain Missing Values

# %% [markdown]
# We need to deal with the rows which contain missing values before building our models to predict loan defeaulters. There is no need to impute the missing values since we have sufficient amount of data. Hence, the rows that contain missing values will be dropped from our dataset.

# %%
df1.dropna(axis=0, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 769128 entries, 42535 to 887378
# Data columns (total 48 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   769128 non-null  float64
#  1   funded_amnt                 769128 non-null  float64
#  2   funded_amnt_inv             769128 non-null  float64
#  3   term                        769128 non-null  object
#  4   int_rate                    769128 non-null  float64
#  5   installment                 769128 non-null  float64
#  6   grade                       769128 non-null  object
#  7   sub_grade                   769128 non-null  object
#  8   emp_title                   769128 non-null  object
#  9   emp_length                  769128 non-null  object
#  10  home_ownership              769128 non-null  object
#  11  annual_inc                  769128 non-null  float64
#  12  verification_status         769128 non-null  object
#  13  issue_d                     769128 non-null  object
#  14  loan_status                 769128 non-null  object
#  15  pymnt_plan                  769128 non-null  object
#  16  purpose                     769128 non-null  object
#  17  title                       769128 non-null  object
#  18  addr_state                  769128 non-null  object
#  19  dti                         769128 non-null  float64
#  20  delinq_2yrs                 769128 non-null  float64
#  21  earliest_cr_line            769128 non-null  object
#  22  inq_last_6mths              769128 non-null  float64
#  23  open_acc                    769128 non-null  float64
#  24  pub_rec                     769128 non-null  float64
#  25  revol_bal                   769128 non-null  float64
#  26  revol_util                  769128 non-null  float64
#  27  total_acc                   769128 non-null  float64
#  28  initial_list_status         769128 non-null  object
#  29  out_prncp                   769128 non-null  float64
#  30  out_prncp_inv               769128 non-null  float64
#  31  total_pymnt                 769128 non-null  float64
#  32  total_pymnt_inv             769128 non-null  float64
#  33  total_rec_prncp             769128 non-null  float64
#  34  total_rec_int               769128 non-null  float64
#  35  total_rec_late_fee          769128 non-null  float64
#  36  recoveries                  769128 non-null  float64
#  37  collection_recovery_fee     769128 non-null  float64
#  38  last_pymnt_amnt             769128 non-null  float64
#  39  last_credit_pull_d          769128 non-null  object
#  40  collections_12_mths_ex_med  769128 non-null  float64
#  41  application_type            769128 non-null  object
#  42  acc_now_delinq              769128 non-null  float64
#  43  tot_coll_amt                769128 non-null  float64
#  44  tot_cur_bal                 769128 non-null  float64
#  45  total_rev_hi_lim            769128 non-null  float64
#  46  issue_month                 769128 non-null  object
#  47  issue_year                  769128 non-null  object
# dtypes: float64(29), object(19)
# memory usage: 287.5+ MB

# %% [markdown]
# #### 3.2 Converting Loan Status into Good or Bad Loan

# %%
# diplay the unique categories of loan status feature
df1.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'Late (31-120 days)', 'Late (16-30 days)',
#        'Charged Off', 'In Grace Period', 'Default', 'Issued'],
#       dtype=object)

# %% [markdown]
# The target feature of this dataset is "Loan Status" which has 8 different categories after dropping the rows with missing values. For the purpose of this project, we need to convert the loan status feature into "Good Loan" or "Bad Loan" based on the description of loan status categories. The categories of "Current", "Fully Paid", and "Issued" were considered as a good loan. The category of "In Grace Period" can be considered to be good or bad depending upon the strictness of investor. It was treated as a good loan in this project. The categories of "Late (16-30 days)", "Late (31-120 days)", "Charged Off" and "Default" were converted to a bad loan.
#
# The dataset is highly imbalanced in the way that the number of bad loans is only 46,539 out of 769,128 which corresponds to 6.05% of the entire dataset.

# %%
# the loan status categories to be coverted to bad loan
bad_loan = ['Charged Off', 'Default', 'Late (16-30 days)','Late (31-120 days)']

def convert_loan_status(status):
    """This function converts the loan status feature into good or bad loan"""
    if status in bad_loan:
        return 'Bad Loan'
    else:
        return 'Good Loan'

# apply the function above to the "loan_status" feature
df1['loan_status'] = df1['loan_status'].apply(convert_loan_status)

# %%
df1['loan_status'] = df1['loan_status'].astype('category').cat.codes

# print the number of good and bad loans
df1.loan_status.value_counts()
# Out:
# 1    722589
# 0     46539
# Name: loan_status, dtype: int64

# %% [markdown]
# #### 3.3 Feature Selection for Object Data Type

# %% [markdown]
# 18 features have object data type in our dataset.

# %%
# select the features with "Object" data type
df1_Obj = df1.select_dtypes(include='object')

df1_Obj.shape
# Out:
# (769128, 18)

# %%
# description of features with "Object" data type
df1_Obj.describe(include=['O'])
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       769128  769128    769128    769128     769128         769128
# unique           2       7        35    259937         11              6
# top      36 months       B        B4   Teacher  10+ years       MORTGAGE
# freq        528375  219127     48199     13453     272311         389615
#
#        verification_status   issue_d pymnt_plan             purpose  \
# count               769128    769128     769128              769128
# unique                   3        41          2                  14
# top        Source Verified  Oct-2015          n  debt_consolidation
# freq                301708     45670     769122              463101
#
#                      title addr_state earliest_cr_line initial_list_status  \
# count               769128     769128           769128              769128
# unique               36725         51              677                   2
# top     Debt consolidation         CA         Aug-2001                   w
# freq                390139     110824             6012              407017
#
#        last_credit_pull_d application_type issue_month issue_year
# count              769128           769128      769128     769128
# unique                 42                2          12          4
# top              Jan-2016       INDIVIDUAL         Oct       2015
# freq               664927           768687      101407     396723

# %% [markdown]
# According to the descriptive statistics of the features that have object data type, several of the features needs to be dropped due to the fact that they have a large number of unique values which leads to memory error. The features with high correlation will also be dropped because only one of them will be sufficient to feed the machine learning models. Lastly, some features will be dropped from the dataset since they do not provide valuable info for further analysis. Those include the following features:
#
#     . emp_title
#     . issue_d
#     . title
#     . addr_state
#     . earliest_cr_line
#     . last_credit_pull_d
#     . funded_amnt
#     . funded_amnt_inv
#     . sub_grade
#     . total_rec_prncp
#     . total_rev_hi_lim
#     . issue_month
#     . issue_year
#     . term
#     . verification_status

# %%
# features to be dropped
df1.drop(['emp_title', 'issue_d', 'title', 'addr_state', 
          'earliest_cr_line', 'last_credit_pull_d', 'funded_amnt',
          'funded_amnt_inv', 'sub_grade','total_rec_prncp', 
          'total_rev_hi_lim', 'issue_month', 'issue_year',
          'term', 'verification_status'], axis=1, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 769128 entries, 42535 to 887378
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   769128 non-null  float64
#  1   int_rate                    769128 non-null  float64
#  2   installment                 769128 non-null  float64
#  3   grade                       769128 non-null  object
#  4   emp_length                  769128 non-null  object
#  5   home_ownership              769128 non-null  object
#  6   annual_inc                  769128 non-null  float64
#  7   loan_status                 769128 non-null  int8
#  8   pymnt_plan                  769128 non-null  object
#  9   purpose                     769128 non-null  object
#  10  dti                         769128 non-null  float64
#  11  delinq_2yrs                 769128 non-null  float64
#  12  inq_last_6mths              769128 non-null  float64
#  13  open_acc                    769128 non-null  float64
#  14  pub_rec                     769128 non-null  float64
#  15  revol_bal                   769128 non-null  float64
#  16  revol_util                  769128 non-null  float64
#  17  total_acc                   769128 non-null  float64
#  18  initial_list_status         769128 non-null  object
#  19  out_prncp                   769128 non-null  float64
#  20  out_prncp_inv               769128 non-null  float64
#  21  total_pymnt                 769128 non-null  float64
#  22  total_pymnt_inv             769128 non-null  float64
#  23  total_rec_int               769128 non-null  float64
#  24  total_rec_late_fee          769128 non-null  float64
#  25  recoveries                  769128 non-null  float64
#  26  collection_recovery_fee     769128 non-null  float64
#  27  last_pymnt_amnt             769128 non-null  float64
#  28  collections_12_mths_ex_med  769128 non-null  float64
#  29  application_type            769128 non-null  object
#  30  acc_now_delinq              769128 non-null  float64
#  31  tot_coll_amt                769128 non-null  float64
#  32  tot_cur_bal                 769128 non-null  float64
# dtypes: float64(25), int8(1), object(7)
# memory usage: 194.4+ MB

# %% [markdown]
# #### 3.4 One Hot Encoding

# %% [markdown]
# After dropping the features with low variance and high correlation, we ended up with 7 features that have "object" data type. These features need to be converted into numerical data type because machine learning algorithms will not work with categorical variables. To convert these features, we can either use "Label Encoder" available in Python or "One Hot Encoder". Since most of the features with "object" data type have multiple categories, it would be inappropriate to use the "Label Encoder". Instead, we will go with "One Hot Encoder" to convert these features into numerical data type.

# %%
df1 = pd.get_dummies(df1, drop_first=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 769128 entries, 42535 to 887378
# Data columns (total 63 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   769128 non-null  float64
#  1   int_rate                    769128 non-null  float64
#  2   installment                 769128 non-null  float64
#  3   annual_inc                  769128 non-null  float64
#  4   loan_status                 769128 non-null  int8
#  5   dti                         769128 non-null  float64
#  6   delinq_2yrs                 769128 non-null  float64
#  7   inq_last_6mths              769128 non-null  float64
#  8   open_acc                    769128 non-null  float64
#  9   pub_rec                     769128 non-null  float64
#  10  revol_bal                   769128 non-null  float64
#  11  revol_util                  769128 non-null  float64
#  12  total_acc                   769128 non-null  float64
#  13  out_prncp                   769128 non-null  float64
#  14  out_prncp_inv               769128 non-null  float64
#  15  total_pymnt                 769128 non-null  float64
#  16  total_pymnt_inv             769128 non-null  float64
#  17  total_rec_int               769128 non-null  float64
#  18  total_rec_late_fee          769128 non-null  float64
#  19  recoveries                  769128 non-null  float64
#  20  collection_recovery_fee     769128 non-null  float64
#  21  last_pymnt_amnt             769128 non-null  float64
#  22  collections_12_mths_ex_med  769128 non-null  float64
#  23  acc_now_delinq              769128 non-null  float64
#  24  tot_coll_amt                769128 non-null  float64
#  25  tot_cur_bal                 769128 non-null  float64
#  26  grade_B                     769128 non-null  uint8
#  27  grade_C                     769128 non-null  uint8
#  28  grade_D                     769128 non-null  uint8
#  29  grade_E                     769128 non-null  uint8
#  30  grade_F                     769128 non-null  uint8
#  31  grade_G                     769128 non-null  uint8
#  32  emp_length_10+ years        769128 non-null  uint8
#  33  emp_length_2 years          769128 non-null  uint8
#  34  emp_length_3 years          769128 non-null  uint8
#  35  emp_length_4 years          769128 non-null  uint8
#  36  emp_length_5 years          769128 non-null  uint8
#  37  emp_length_6 years          769128 non-null  uint8
#  38  emp_length_7 years          769128 non-null  uint8
#  39  emp_length_8 years          769128 non-null  uint8
#  40  emp_length_9 years          769128 non-null  uint8
#  41  emp_length_< 1 year         769128 non-null  uint8
#  42  home_ownership_MORTGAGE     769128 non-null  uint8
#  43  home_ownership_NONE         769128 non-null  uint8
#  44  home_ownership_OTHER        769128 non-null  uint8
#  45  home_ownership_OWN          769128 non-null  uint8
#  46  home_ownership_RENT         769128 non-null  uint8
#  47  pymnt_plan_y                769128 non-null  uint8
#  48  purpose_credit_card         769128 non-null  uint8
#  49  purpose_debt_consolidation  769128 non-null  uint8
#  50  purpose_educational         769128 non-null  uint8
#  51  purpose_home_improvement    769128 non-null  uint8
#  52  purpose_house               769128 non-null  uint8
#  53  purpose_major_purchase      769128 non-null  uint8
#  54  purpose_medical             769128 non-null  uint8
#  55  purpose_moving              769128 non-null  uint8
#  56  purpose_other               769128 non-null  uint8
#  57  purpose_renewable_energy    769128 non-null  uint8
#  58  purpose_small_business      769128 non-null  uint8
#  59  purpose_vacation            769128 non-null  uint8
#  60  purpose_wedding             769128 non-null  uint8
#  61  initial_list_status_w       769128 non-null  uint8
#  62  application_type_JOINT      769128 non-null  uint8
# dtypes: float64(25), int8(1), uint8(37)
# memory usage: 180.4 MB

# %% [markdown]
# # 4. Model Building (Imbalanced Data)

# %% [markdown]
# As mentioned above, our target feature of loan status is highly imbalanced. Therefore, we would like to see if balancing the data makes difference in predicting bad loans. But first, we want to go with the unbalanced data. Following that, we will balance the data using SMOTE and compare the results.
#
# In this section, 3 machine learning algorithm will be used to predict bad loans which include logistic regression, decision tree, and random forest.

# %% [markdown]
# #### 4.1 Splitting Data into Training and Test Sets

# %%
# extract the features and the response variable
y = df1['loan_status']
X = df1.drop('loan_status', axis=1)

# %%
# Splitting the dataset in training (75%) and testing set (25%)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42,
                                                    stratify=y)

# %% [markdown]
# #### 4.2 Feature Scaling

# %% [markdown]
# Here, we scaled train and test dataset using Scikit-learn's StandardScaler which standardize features by removing the mean and scaling to unit variance. The scaling performed only on continuous numeric features. Categorical features that were converted to dummy variables were excluded from scaling.

# %%
# scale X_train numeric continuous features
scaler = StandardScaler()
numeric_cols = X_train.columns[(X_train.dtypes == 'float64') | (X_train.dtypes == 'int64')].to_list()
scaler.fit(X_train[numeric_cols])
X_train[numeric_cols] = scaler.transform(X_train[numeric_cols])

# %%
# scale X_test numeric continuous features
numeric_cols = X_test.columns[(X_test.dtypes == 'float64') | (X_test.dtypes == 'int64')].to_list()
X_test[numeric_cols] = scaler.transform(X_test[numeric_cols])

# %%
y_train.value_counts()
# Out:
# 1    541942
# 0     34904
# Name: loan_status, dtype: int64

# %% [markdown]
# #### 4.3 Model Fitting

# %% [markdown]
#     . Logistic Regression
#     . Decision Tree
#     . Random Forest

# %% [markdown]
# #### 4.3.1 Logistic Regression

# %% [markdown]
# Logistic regression is our first candidate for model algorithms. After performing 3-fold cross-validation, logistic regression provides an average accuracy score of 0.98. Since the data is highly imbalanced, we also provided some model evaluation reports such as confusion matrix and classification report which will be used to evaluate and compare our models.
#
# The logistic regression did pretty well in predicting the good and bad loans.

# %%
# instantiate Logistic Regression
logreg = LogisticRegression(max_iter=1000)

# Compute 3-fold cross-validation scores
logreg_cv = cross_val_score(logreg, X_train, y_train, cv=3, scoring='accuracy')

# Print the 3-fold cross-validation scores
print("Average 3-Fold CV Accuracy Score: {}".format(np.mean(logreg_cv)))
# Out:
# Average 3-Fold CV Accuracy Score: 0.98083717317967

# %%
# model prediction for logistic regression
# Fit it to the data
logreg.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = logreg.predict(X_test)

# generate the classification report
print(classification_report(y_test, y_pred))

# plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
ax = sns.heatmap(cm, cmap='viridis_r', annot=True, fmt='d', square=True)
ax.set_xlabel('Predicted Value')
ax.set_ylabel('Actual Value')
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# display the plot
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.81     11635
#            1       0.98      1.00      0.99    180647
#
#     accuracy                           0.98    192282
#    macro avg       0.98      0.84      0.90    192282
# weighted avg       0.98      0.98      0.98    192282

# %% [markdown]
# #### 4.3.2 Decision Tree

# %% [markdown]
# Our second candidate for the model algortithms is decision tree. Again, we performed 3-fold cross validation to see average accuracy score. The model resulted with an average accuracy score of 0.96.
#
# The results for the confusion matrix and classification report also look good. But logistic regression performed better at this point.

# %%
# instantiate a Decision Tree classifier
tree = DecisionTreeClassifier()

# compute 3-fold cross-validation scores
tree_cv = cross_val_score(tree, X_train, y_train, cv=3, scoring='accuracy')

# Print the 3-fold cross-validation scores
print("Average 3-Fold CV Accuracy Score: {}".format(np.mean(tree_cv)))
# Out:
# Average 3-Fold CV Accuracy Score: 0.9631028038679301

# %%
# model prediction for decision tree
# Fit it to the data
tree.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = tree.predict(X_test)

# generate the classification report
print(classification_report(y_test, y_pred))

# plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
ax = sns.heatmap(cm, cmap='viridis_r', annot=True, fmt='d', square=True)
ax.set_xlabel('Predicted Value')
ax.set_ylabel('Actual Value')
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# display the plot
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70     11635
#            1       0.98      0.98      0.98    180647
#
#     accuracy                           0.96    192282
#    macro avg       0.83      0.85      0.84    192282
# weighted avg       0.96      0.96      0.96    192282

# %% [markdown]
# #### 4.3.3 Random Forest

# %% [markdown]
# The same operation for cross-validation were performed here again. The random forest algorithm provides an average accuracy score of 0.977 which is better than the decision tree but not as good as the logistic regression. The comparison of confusion matrix and classification report also indicate that the logistic regression is better at predicting good and bad loans.

# %%
# instantiate Random Forest Classifier
ranfor = RandomForestClassifier(n_estimators=3)

# compute 3-fold cross-validation scores
ranfor_cv = cross_val_score(ranfor, X_train, y_train, cv=3, scoring='accuracy')

# Print the 3-fold cross-validation scores
print("Average 3-Fold CV Accuracy Score: {}".format(np.mean(ranfor_cv)))
# Out:
# Average 3-Fold CV Accuracy Score: 0.9771862854210656

# %%
# model prediction for random forest
# Fit it to the data
ranfor.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = ranfor.predict(X_test)

# generate the classification report
print(classification_report(y_test, y_pred))

# plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
ax = sns.heatmap(cm, cmap='viridis_r', annot=True, fmt='d', square=True)
ax.set_xlabel('Predicted Value')
ax.set_ylabel('Actual Value')
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# display the plot
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.68      0.78     11635
#            1       0.98      1.00      0.99    180647
#
#     accuracy                           0.98    192282
#    macro avg       0.95      0.84      0.89    192282
# weighted avg       0.98      0.98      0.98    192282

# %% [markdown]
# # 5. Model Building (Balanced Data)

# %% [markdown]
# Here, we will balance the number of good and bad loans using Synthetic Minority Oversampling Technique(SMOTE). We will be oversampling the minority class of bad loans to 300,000 and perform the same machine learning algorithms again.

# %% [markdown]
# #### 5.1 Balancing Training Dataset - SMOTE

# %%
# extract the features and the response variable
y = df1['loan_status']
X = df1.drop('loan_status', axis=1)

# %%
# Splitting the dataset in training (75%) and testing set (25%)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    random_state=42,
                                                    stratify=y)

# %%
# scale X_train numeric continuous features
scaler = StandardScaler()
numeric_cols = X_train.columns[(X_train.dtypes == 'float64') | (X_train.dtypes == 'int64')].to_list()
scaler.fit(X_train[numeric_cols])
X_train[numeric_cols] = scaler.transform(X_train[numeric_cols])

# scale X_test numeric continuous features
numeric_cols = X_test.columns[(X_test.dtypes == 'float64') | (X_test.dtypes == 'int64')].to_list()
X_test[numeric_cols] = scaler.transform(X_test[numeric_cols])

# %%
# oversampling using SMOTE
sm = SMOTE(random_state=27, sampling_strategy={1:541942, 0:300000})
X_train, y_train = sm.fit_sample(X_train, y_train)

# %%
y_train.value_counts()
# Out:
# 1    541942
# 0    300000
# Name: loan_status, dtype: int64

# %% [markdown]
# #### 5.2 Model Fitting

# %% [markdown]
#  Candidates for Model Algorithms:
#
#     . Logistic Regression
#     . Decision Tree
#     . Random Forest

# %% [markdown]
# #### 5.2.1 Logistic Regression

# %%
# instantiate Logistic Regression
logreg = LogisticRegression(max_iter=1000)

# Compute 3-fold cross-validation scores
logreg_cv = cross_val_score(logreg, X_train, y_train, cv=3, scoring='accuracy')

# Print the 3-fold cross-validation scores
print("Average 3-Fold CV Accuracy Score: {}".format(np.mean(logreg_cv)))
# Out:
# Average 3-Fold CV Accuracy Score: 0.9472374778639098

# %%
# model prediction for logistic regression
# Fit it to the data
logreg.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = logreg.predict(X_test)

# generate the classification report
print(classification_report(y_test, y_pred))

# plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
ax = sns.heatmap(cm, cmap='viridis_r', annot=True, fmt='d', square=True)
ax.set_xlabel('Predicted Value')
ax.set_ylabel('Actual Value')
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# display the plot
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72     11635
#            1       0.98      0.98      0.98    180647
#
#     accuracy                           0.97    192282
#    macro avg       0.85      0.85      0.85    192282
# weighted avg       0.97      0.97      0.97    192282

# %% [markdown]
# #### 5.2.2 Decision Tree

# %%
# instantiate a Decision Tree classifier
tree = DecisionTreeClassifier()

# compute 3-fold cross-validation scores
tree_cv = cross_val_score(tree, X_train, y_train, cv=3, scoring='accuracy')

# Print the 3-fold cross-validation scores
print("Average 3-Fold CV Accuracy Score: {}".format(np.mean(tree_cv)))
# Out:
# Average 3-Fold CV Accuracy Score: 0.951785284385933

# %%
# model prediction for decision tree
# Fit it to the data
tree.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = tree.predict(X_test)

# generate the classification report
print(classification_report(y_test, y_pred))

# plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
ax = sns.heatmap(cm, cmap='viridis_r', annot=True, fmt='d', square=True)
ax.set_xlabel('Predicted Value')
ax.set_ylabel('Actual Value')
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# display the plot
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.73      0.64     11635
#            1       0.98      0.96      0.97    180647
#
#     accuracy                           0.95    192282
#    macro avg       0.78      0.85      0.81    192282
# weighted avg       0.96      0.95      0.95    192282

# %% [markdown]
# #### 5.2.3 Random Forest

# %%
# instantiate Random Forest Classifier
ranfor = RandomForestClassifier(n_estimators=3)

# compute 3-fold cross-validation scores
ranfor_cv = cross_val_score(ranfor, X_train, y_train, cv=3, scoring='accuracy')

# Print the 3-fold cross-validation scores
print("Average 3-Fold CV Accuracy Score: {}".format(np.mean(ranfor_cv)))
# Out:
# Average 3-Fold CV Accuracy Score: 0.9504205881827062

# %%
# model prediction for random forest
# Fit it to the data
ranfor.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = ranfor.predict(X_test)

# generate the classification report
print(classification_report(y_test, y_pred))

# plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
ax = sns.heatmap(cm, cmap='viridis_r', annot=True, fmt='d', square=True)
ax.set_xlabel('Predicted Value')
ax.set_ylabel('Actual Value')
# bottom, top = ax.get_ylim()
# ax.set_ylim(bottom + 0.5, top - 0.5)

# display the plot
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69     11635
#            1       0.98      0.98      0.98    180647
#
#     accuracy                           0.96    192282
#    macro avg       0.83      0.84      0.83    192282
# weighted avg       0.96      0.96      0.96    192282

# %% [markdown]
# Since the random forest classifier is built upon decision tree, we can plot the feature importance. It is an useful technique to understand which features (top 10 here) had the highest importance in predicting an outcome variable which is the loan status in our case.
#
# As can be seen from the graph below, `"recoveries"`, `"out_prncp_inv"`, and `"collection_recovery_fee"` are the 3 most important features in predicting good and bad loans.

# %%
# feature importance
feat = X_train.columns
imp = ranfor.feature_importances_
df = pd.DataFrame({'Feature': feat, 'Importance': imp})
df = df.sort_values('Importance', ascending=False)[:10]
sns.barplot(x='Importance', y='Feature', data=df);

# %% [markdown]
# Across models, even though the decision tree model provided the highest accuracy score, it is not doing as well as the logistic regression and random forest in predicting good and bad loans based on the results of the confusion matrix and classification report.

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# We succesfully built a machine learning algorithm which predicts good and bad loans. The exploratory data analysis and machine learning algorithm can help the LendingClub identify risky loans.
#
# When we were working on this project, the LendingClub revealed data for years between 2015 and 2018. We can update our dataset by adding these years and see the number of current loans which were defaulted or charged off. The new data can also be added in our current dataset to improve our training data.
